# %% [markdown]
# COGNIFYZ TECHNOLOGIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data_set.csv")

# %% [markdown]
# Level 1: Beginner

# %% [markdown]
# Task 1: Data Overview

# %%
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df.isnull()
# Out:
#     gender    age  Investment_Avenues  Mutual_Funds  Equity_Market  \
# 0    False  False               False         False          False
# 1    False  False               False         False          False
# 2    False  False               False         False          False
# 3    False  False               False         False          False
# 4    False  False               False         False          False
# 5    False  False               False         False          False
# 6    False  False               False         False          False
# 7    False  False               False         False          False
# 8    False  False               False         False          False
# 9    False  False               False         False          False
# 10   False  False               False         False          False
# 11   False  False               False         False          False
# 12   False  False               False         False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %% [markdown]
# Task 2: Gender Distribution

# %%
gender_count = df['gender'].value_counts()

# %%
gender_count
# Out:
# gender
# Male      25
# Female    15
# Name: count, dtype: int64

# %%
gender_count.plot(kind='bar',color=['green','red'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_count.plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# Level 2: Intermediate

# %% [markdown]
# Task 3: Descriptive Statistics

# %%
num_col = df.select_dtypes(include=['float64','int64']).columns
num_col
# Out:
# Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %% [markdown]
# basic stastical

# %%
for col in num_col:
    mean=df[col].mean()
    median=df[col].median()
    std_dev=df[col].std()
    print (f"{col}:mean={mean}, median={median}, std={std_dev}")
# Out:
# age:mean=27.8, median=27.0, std=3.560466693696639
# Mutual_Funds:mean=2.55, median=2.0, std=1.1972189997378648
# Equity_Market:mean=3.475, median=4.0, std=1.1319939294935533
# Debentures:mean=5.75, median=6.5, std=1.6756169931378433
# Government_Bonds:mean=4.65, median=5.0, std=1.3690723042845383
# Fixed_Deposits:mean=3.575, median=3.5, std=1.7958284996067968
# PPF:mean=2.025, median=1.0, std=1.6090688500193404
# Gold:mean=5.975, median=6.0, std=1.1432634351063986

# %% [markdown]
# Task 4: Most Preferred Investment Avenue

# %%
#Extract inveastment coloumn releated to different investment avenue

# %%
investment_col = ['Mutual_Funds','Equity_Market','Debentures','Government_Bonds','Fixed_Deposits','PPF','Gold']

# %%
#sum the occurences for each invest_ave

# %%
investment_freq = df[investment_col].sum()

# %%
#display the frequency of each  investment_ave

# %%
print("frequency of each investment_ave:")
print(investment_freq)
# Out:
# frequency of each investment_ave:
# Mutual_Funds        102
# Equity_Market       139
# Debentures          230
# Government_Bonds    186
# Fixed_Deposits      143
# PPF                  81
# Gold                239
# dtype: int64

# %%
#most preferread inveatment_ave

# %%
most_pre_inv = investment_freq.idxmax()
most_pre_inv
# Out:
# 'Gold'

# %%
most_pre_freq = investment_freq.max()
most_pre_freq
# Out:
# 239

# %%
print(f"The most preferread inveatment_ave is {most_pre_inv} with  {most_pre_freq} occurrence")
# Out:
# The most preferread inveatment_ave is Gold with  239 occurrence

# %% [markdown]
# Level 3: Advanced

# %% [markdown]
#  Task 5: Reasons for Investment

# %%
#Extract relevant columns related to reasons for investment choices

# %%
reason_col = ['Reason_Equity','Reason_Mutual','Reason_Bonds','Reason_FD']

# %%
#display the unique value in each reason col to identify common themes

# %%
reason_summry = {col:df[col].value_counts() for col in reason_col}

# %%
for col,summary in reason_summry.items():
    print(f"Unique values in {col}:")
    print(summary)
    print(f"SUMMARY OF {col}:")
# Out:
# Unique values in Reason_Equity:
# Reason_Equity
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: count, dtype: int64
# SUMMARY OF Reason_Equity:
# Unique values in Reason_Mutual:
# Reason_Mutual
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: count, dtype: int64
# SUMMARY OF Reason_Mutual:
# Unique values in Reason_Bonds:
# Reason_Bonds
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: count, dtype: int64
# SUMMARY OF Reason_Bonds:
# Unique values in Reason_FD:
# Reason_FD
# Risk Free              19
# Fixed Returns          18
# High Interest Rates     3
# Name: count, dtype: int64
# SUMMARY OF Reason_FD:

# %% [markdown]
# Task 6: Savings Objectives

# %%
saving_objective_col = 'What are your saving objectives?'

# %%
saving_objective_summary =df['Objective'].value_counts()

# %%
print("summary of saving objective:")
print(saving_objective_summary)
# Out:
# summary of saving objective:
# Objective
# Capital Appreciation    26
# Growth                  11
# Income                   3
# Name: count, dtype: int64

# %%
print("Detailed Description of main Savings Objectives")
# Out:
# Detailed Description of main Savings Objectives

# %%
for objective, count in saving_objective_summary.items():
    print(f"-{objective}: {count} mentions")
# Out:
# -Capital Appreciation: 26 mentions
# -Growth: 11 mentions
# -Income: 3 mentions

# %% [markdown]
# Level 4: Expert

# %% [markdown]
# Task 7: Common Information Sources

# %%
information_source_col = 'Source'

# %%
information_source_summary =df[information_source_col].value_counts()

# %%
print("summary of information sources:")
print(information_source_summary)
# Out:
# summary of information sources:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %% [markdown]
# Task 8: Investment Duration

# %%
def convert_duration_to_years(Duration):
    if Duration == "less than 1 years":
        return 0.5
    elif Duration == "1-3 years":
        return 2
    elif Duration == "more than5  years":
        return 4
    elif Duration == "more than 5 years":
        return 6
    else:
        return  None

# %%
investment_duration =df['Duration']

# %%
numerical_durations = investment_duration.apply(convert_duration_to_years)
numerical_durations
# Out:
# 0     2.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     2.0
# 6     NaN
# 7     NaN
# 8     2.0
# 9     NaN
# 10    NaN
# 11    2.0
# 12    2.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    2.0
# 28    2.0
# 29    NaN
# 30    2.0
# 31    NaN
# 32    NaN
# 33    2.0
# 34    2.0
# 35    NaN
# 36    2.0
# 37    NaN
# 38    2.0
# 39    NaN
# Name: Duration, dtype: float64

# %%
average_duration = numerical_durations.mean()
average_duration
# Out:
# 2.0

# %%
print(f"average investment duration: {average_duration:.2f}years")
# Out:
# average investment duration: 2.00years

# %%
expectations_column = 'Expect'

# %%
print("Sample data from the Expectations column:")
print(df[expectations_column].head())
# Out:
# Sample data from the Expectations column:
# 0    20%-30%
# 1    20%-30%
# 2    20%-30%
# 3    10%-20%
# 4    20%-30%
# Name: Expect, dtype: object

# %%
expectations_summary = df[expectations_column].value_counts()

# %%
print("Summary of Participants' Expect:")
print(expectations_summary)
# Out:
# Summary of Participants' Expect:
# Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64

# %% [markdown]
# Task 10: Correlation Analysis

# %%
col_of_interest = ['age', 'Duration', 'Expect']
data = df[col_of_interest]

# %%
data
# Out:
#     age           Duration   Expect
# 0    34          1-3 years  20%-30%
# 1    23  More than 5 years  20%-30%
# 2    30          3-5 years  20%-30%
# 3    22   Less than 1 year  10%-20%
# 4    24   Less than 1 year  20%-30%
# 5    24          1-3 years  30%-40%
# 6    27          3-5 years  20%-30%
# 7    21          3-5 years  20%-30%
# 8    35          1-3 years  20%-30%
# 9    31          3-5 years  30%-40%
# 10   35          3-5 years  20%-30%
# 11   29          1-3 years  20%-30%
# 12   21          1-3 years  20%-30%
# 13   28          1-3 years  20%-30%
# 14   25          1-3 years  20%-30%
# 15   27          1-3 years  20%-30%
# 16   28          1-3 years  20%-30%
# 17   27          1-3 years  20%-30%
# 18   29          1-3 years  20%-30%
# 19   26          3-5 years  20%-30%
# 20   29          3-5 years  20%-30%
# 21   24          3-5 years  20%-30%
# 22   27          3-5 years  20%-30%
# 23   25          3-5 years  20%-30%
# 24   26          3-5 years  30%-40%
# ...

# %%
print("sample data for correlation analysis:")
print(data.head())
# Out:
# sample data for correlation analysis:
#    age           Duration   Expect
# 0   34          1-3 years  20%-30%
# 1   23  More than 5 years  20%-30%
# 2   30          3-5 years  20%-30%
# 3   22   Less than 1 year  10%-20%
# 4   24   Less than 1 year  20%-30%

# %%
def convert_duration_to_years(Duration):
    if Duration == "less than 1 years":
        return 0.5
    elif Duration == "1-3 years":
        return 2
    elif Duration == "more than5  years":
        return 4
    elif Duration == "more than 5 years":
        return 6
    else:
        return  None

# %%
df['Investment_Duration_Years'] = df['Duration'].apply(convert_duration_to_years)

# %%
col_of_interest = ['age', 'Duration', 'Expect']
data = df[col_of_interest]
data
# Out:
#     age           Duration   Expect
# 0    34          1-3 years  20%-30%
# 1    23  More than 5 years  20%-30%
# 2    30          3-5 years  20%-30%
# 3    22   Less than 1 year  10%-20%
# 4    24   Less than 1 year  20%-30%
# 5    24          1-3 years  30%-40%
# 6    27          3-5 years  20%-30%
# 7    21          3-5 years  20%-30%
# 8    35          1-3 years  20%-30%
# 9    31          3-5 years  30%-40%
# 10   35          3-5 years  20%-30%
# 11   29          1-3 years  20%-30%
# 12   21          1-3 years  20%-30%
# 13   28          1-3 years  20%-30%
# 14   25          1-3 years  20%-30%
# 15   27          1-3 years  20%-30%
# 16   28          1-3 years  20%-30%
# 17   27          1-3 years  20%-30%
# 18   29          1-3 years  20%-30%
# 19   26          3-5 years  20%-30%
# 20   29          3-5 years  20%-30%
# 21   24          3-5 years  20%-30%
# 22   27          3-5 years  20%-30%
# 23   25          3-5 years  20%-30%
# 24   26          3-5 years  30%-40%
# ...

# %%
data = data.apply(pd.to_numeric, errors='coerce')

# %%
data = data.dropna()

# %%
print("Check for NaN values after conversion:")
print(data.isna().sum())
# Out:
# Check for NaN values after conversion:
# age         0
# Duration    0
# Expect      0
# dtype: int64

# %%
correlation_matrix = data.corr()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#           age  Duration  Expect
# age       NaN       NaN     NaN
# Duration  NaN       NaN     NaN
# Expect    NaN       NaN     NaN

# %%
sns.pairplot(data)
plt.suptitle('Scatter Plot Matrix', y=1.02)
plt.show()
